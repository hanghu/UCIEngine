# %%
from base import UCIEngine
from visualization import visualize_1e_inter_cat_interactions
import numpy as np

# %%
MRCISD = [[3,2,0],
          [3,1,1],
          [2,3,0],
          [2,2,1],
          [3,0,2],
          [2,1,2],
          [1,4,0],
          [1,3,1],
          [1,2,2]]

# %%
FCI = []
for i in range(7):
    for j in range(7):
        for k in range(7):
            #for l in range(4):
                if i+j+k==9: #+l == 5:
                    FCI.append([k,j,i])

# %%
A = UCIEngine(NOs=[6,6,6],NE=9, init_by='Cat',
              Cats_occ=FCI)

# %% [markdown]
# ### Visualization 1e-Inter-Category Interactions

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(10,10))


options = {
    'node_size': 1000,
    'width': 3,
    'arrowstyle': '-|>',
    'arrowsize': 12,
    'alpha': 1.0,
    'font_size':20
}


visualize_1e_inter_cat_interactions(A, ax=ax, show_edges=True,options=options)
